# %%
raw_data ="  AhMeT  yILMAZ ;  23 ;  1.78 ;  ahmetYILMAZ@GMAIL.Com   "
new_data = raw_data.strip().split(";")
new_data

# %%
isim_adi   = new_data[0].strip().lower().split()[0].title()
isim_soyad = new_data[0].strip().lower().split()[1].title()
isim = isim_adi + " " + isim_soyad

# %%
yas = int(new_data[1].strip())
yeni_yas = float(yas + 10)
print("Yaş (10 yıl sonra):", yeni_yas)

# %%
boy = float(new_data[2].strip())
boy_cm = boy * 100
print("Boy (cm):", boy_cm )

# %%
email = new_data[3].strip().lower()
email_kod = email[:email.find("@")][:3]
print("Email kullanıcı kodu:", email_kod)
